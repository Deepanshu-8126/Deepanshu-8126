# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepanshu-8126/Deepanshu-8126/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr= np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]
